# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 72.8 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 106.6 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'လ်': 57631,
#  'ტული': 196059,
#  'utshila': 214562,
#  'န္တရာယ်': 213431,
#  '▁තරම්': 93833,
#  '▁7:9,': 88695,
#  '▁einki': 102442,
#  '▁ඊට': 92165,
#  '▁ವಿಜ್ಞಾನ': 204149,
#  '▁ຕົນ': 123406,
#  '▁umt': 197300,
#  '列入': 234294,
#  '▁хворо': 155397,
#  '▁pārba': 53666,
#  '▁스타일': 141101,
#  'పే': 115705,
#  'بتۇر': 227222,
#  '▁ਅੱਖਾਂ': 223527,
#  '▁Decisão': 202411,
#  'omų': 115963,
#  '▁olabilir': 38369,
#  '▁destes': 113886,
#  'seleyo': 214248,
#  '▁øllum': 64187,
#  'ゴ': 250631,
#  'bred': 94378,
#  '▁قۇي': 173216,
#  '▁Hakanan': 197584,
#  'ସ୍କ': 57941,
#  'гаа': 7011,
#  '▁придо': 105143,
#  'vla': 163333,
#  '▁ankapobeny': 174857,
#  '▁berpartisipasi': 220283,
#  'љима': 156918,
#  '▁holy': 175266,
#  'embris': 141156,
#  '▁malsupren': 245506,
#  'ಗಳು': 5918,
#  '▁прибу': 163215,
#  '▁lanmè': 243008,
#  'əhər': 95764,
#  '▁Proses': 184371,
#  '順': 251740,
#  '▁மேலும்': 48278,
#  '▁abia': 151857,
#  '▁ũũ': 23272,
#  '▁Yhdysval': 89613,
#  '▁پنهنجي': 24954,
#  '▁लगातार': 78019,
#  '▁حقئ': 111497,
#  '▁omu': 15724,
#  'akayo': 213667,
#  '▁ಬಹು': 59626,
#  '▁Sun': 22092,
#  '▁акција': 214874,
#  '▁direkte': 47561,
#  'ຂ້ອຍ': 42180,
#  'rž': 28936,
#  '▁יעדער': 75196,
#  '▁vertr': 42101,
#  '▁whakamatautau': 204411,
#  '▁гне': 141094,
#  '及び': 31004,
#  '▁paba': 64281,
#  'egga': 198973,
#  'vuto': 230229,
#  '▁uhla': 226464,
#  'пера': 11836,
#  '▁canlı': 135649,
#  '▁যথে': 83659,
#  'oleng': 202467,
#  '▁बाहिर': 90698,
#  'mill': 156163,
#  '▁Resort': 179188,
#  '▁Magari': 202145,
#  '▁kihív': 187629,
#  '▁hadi': 26256,
#  '▁mhijiex': 221605,
#  '▁civili': 162890,
#  '▁TL': 154118,
#  '▁Karon': 92338,
#  'sõng': 240427,
#  '▁ଡା': 59901,
#  '▁eig': 27685,
#  '▁கீ': 75465,
#  'の一つ': 49970,
#  'ଯାଏ': 83721,
#  '▁गर्ने': 27725,
#  '▁বাহি': 96228,
#  '▁Nun': 15560,
#  '형': 250016,
#  '▁இருப்ப': 46313,
#  '▁bèn': 152192,
#  '▁ngagaduhan': 108072,
#  'יינע': 121732,
#  'відки': 208815,
#  '▁tờ': 141783,
#  '▁Nhiều': 97283,
#  '▁алды': 14479,
#  '▁चयन': 79233,
#  ');': 12387,
#  '▁lokale': 57646,
#  'fundzi': 109559,
#  '▁उत्पाद': 46498,
#  '▁lambar': 177393,
#  'yahudi': 230284,
#  '奈': 253656,
#  '▁વ્યવ': 44994,
#  'நீங்கள்': 212607,
#  'etimo': 222402,
#  '▁عبد': 141910,
#  '▁ඈ': 119054,
#  '▁сіль': 222268,
#  'brau': 116038,
#  '▁दुर्': 48252,
#  '▁ಮೂರು': 84403,
#  '▁соат': 218772,
#  '▁kolelua': 238491,
#  '▁manus': 55894,
#  'Թ': 251322,
#  '▁kauf': 173033,
#  'ektori': 145408,
#  'legur': 106717,
#  '▁thảm': 174071,
#  '▁اؤلوم': 109764,
#  '▁দেখতে': 58524,
#  '▁qaama': 184354,
#  '▁нега': 64268,
#  '▁uñ': 7376,
#  '▁pp': 136914,
#  'caria': 163964,
#  'ắm': 38192,
#  'ោរព': 195242,
#  'aksikan': 164641,
#  '틱': 252879,
#  '▁Eiropā': 192483,
#  '▁ezahlukeneyo': 141650,
#  'ཟ': 249226,
#  '▁abiɛsa': 133320,
#  '▁yänak': 243016,
#  '▁ns': 3082,
#  '▁Alioze': 143493,
#  '▁čem': 118305,
#  'Į': 251632,
#  '▁kemur': 40590,
#  '▁achiti': 158510,
#  '▁ඉක්': 129082,
#  'ently': 44833,
#  '▁Sebagai': 56615,
#  '▁য়': 36573,
#  'inkun': 190359,
#  '▁ayant': 80103,
#  '▁שוא': 184591,
#  '▁Sei': 32978,
#  'wasị': 49459,
#  'oločenstva': 125629,
#  '心理学': 241474,
#  '▁byrjar': 225574,
#  '无法': 145332,
#  '▁Uporab': 206174,
#  'лов': 19168,
#  '▁indraindray': 233588,
#  '▁다니': 75858,
#  '▁pernikahan': 148220,
#  '▁atya': 108760,
#  '▁조': 5580,
#  '▁BCE': 79400,
#  '▁राम्रो': 56432,
#  'ഷ്യ': 36589,
#  '▁bǎ': 209568,
#  '▁耶和华': 142671,
#  '▁BC': 60145,
#  '▁wanita': 24682,
#  '▁Efesus': 230660,
#  '▁pm': 101439,
#  '▁Unë': 48711,
#  '▁विश्लेषण': 110795,
#  'ိူၼ်ႈ': 122157,
#  '▁concurr': 168879,
#  '▁ɛwɛ': 137143,
#  '▁nøyak': 176771,
#  '▁지원': 28781,
#  '▁putri': 167877,
#  '▁mestre': 208614,
#  '▁Бе': 17663,
#  '▁extra': 23362,
#  '▁Mər': 230425,
#  '▁қою': 98614,
#  '▁administrasi': 209937,
#  '▁ലള': 237367,
#  '▁ਪਤਾ': 58378,
#  '▁adnabod': 175213,
#  '▁byus': 142504,
#  '舞台': 137934,
#  '▁exe': 33082,
#  '▁大': 16991,
#  '▁buộc': 66915,
#  '▁data': 6067,
#  '▁kirang': 150231,
#  '▁зустрічі': 236478,
#  'ያስ': 35316,
#  '▁Buh': 69862,
#  '▁□': 17806,
#  '▁gukorwa': 237315,
#  '▁2:14)': 225391,
#  'óság': 33583,
#  '▁نحن': 36325,
#  '▁signal': 76122,
#  '▁قارار': 219069,
#  '▁efficace': 162821,
#  'ேய': 56379,
#  '▁نیستم': 156128,
#  '▁mafai': 12321,
#  'сьці': 80583,
#  'ၢတ်ႇ': 154262,
#  '▁iedzīv': 62198,
#  '▁borib': 200535,
#  '▁dzem': 106418,
#  '▁Jab': 81998,
#  'larına': 26812,
#  '▁κανέναν': 202673,
#  '▁말하였다': 192373,
#  '▁reki': 133305,
#  '▁xüs': 118304,
#  '▁arusa': 223795,
#  'ી': 248413,
#  'adwa': 85768,
#  '▁सिक्': 160660,
#  'はまた': 112572,
#  'paragrafu': 31717,
#  '▁نت': 26375,
#  '▁kumeke': 198158,
#  'laaju': 213668,
#  '▁dhibaato': 198283,
#  'ວາງ': 113515,
#  'национа': 232654,
#  '▁မိန်းမ': 193726,
#  '▁بذ': 232391,
#  'に入れ': 194925,
#  '▁shaloi': 72203,
#  '▁ደህን': 215782,
#  'ኾ': 250725,
#  'ть': 885,
#  '▁Vec': 202589,
#  '▁градот': 111781,
#  '▁condition': 78999,
#  'ሃል።': 191878,
#  'ofeka': 162190,
#  '▁bangai': 231987,
#  '▁پەقەت': 30386,
#  '▁aplik': 18968,
#  'rän': 62962,
#  '▁nyerahang': 243459,
#  'hawm': 54016,
#  '▁Jok': 35988,
#  'ચ્છા': 103581,
#  '▁stvari': 27517,
#  'siyon': 105660,
#  '▁таңда': 97260,
#  'хов': 94958,
#  '▁নিয়ম': 85878,
#  '▁arday': 226039,
#  '▁yardımcı': 69178,
#  '▁ವರ್ಷಗಳಲ್ಲಿ': 197598,
#  '▁Aote': 171320,
#  '▁lingua': 65258,
#  '▁producir': 146160,
#  '▁lle': 8304,
#  '▁Gulf': 198785,
#  'чес': 8724,
#  '▁даярлау': 217084,
#  '▁பெய': 59682,
#  'sun': 17095,
#  'を必要とする': 202648,
#  '▁Nk': 13241,
#  'ୁଲ': 49708,
#  '▁Pathian': 23722,
#  'یەکانی': 96469,
#  '▁terk': 54179,
#  '製造': 46283,
#  '落ち': 52145,
#  'ంట్లో': 118572,
#  '▁tolas': 179645,
#  '▁પો': 15162,
#  'lakbay': 143418,
#  'tuara': 165238,
#  '▁berk': 12006,
#  'varja': 226915,
#  '▁Chip': 86705,
#  '▁नहि': 19653,
#  'גוד': 240752,
#  '▁жағдайлар': 157890,
#  'ଈ': 253381,
#  '▁adwum': 245247,
#  '▁çalışıyor': 186013,
#  '▁jouluku': 210181,
#  '▁જુદા': 195281,
#  '▁interpret': 44152,
#  '▁mashar': 242471,
#  '▁zabora': 105277,
#  'ఞ': 252118,
#  '倫': 252439,
#  'olak': 94261,
#  'ongom': 36784,
#  'setzung': 142058,
#  '▁sentirias': 179861,
#  'кон': 8599,
#  '▁rætt': 50849,
#  '▁చెప్పింది': 217103,
#  'ọma': 133890,
#  '▁Allohning': 97072,
#  '▁활성화': 207128,
#  '▁পরিচয়': 232850,
#  '▁follo': 83408,
#  '▁forklarer': 210066,
#  '▁omgang': 226657,
#  '▁जिम्मेदार': 198735,
#  'ंसा': 68783,
#  '窓': 252998,
#  '▁जि': 9546,
#  'ಆ': 249286,
#  '▁مطال': 18693,
#  '▁kweng': 202503,
#  'aguzi': 139436,
#  'ɗaa': 121936,
#  '▁Abụ': 155074,
#  'ső': 113371,
#  '▁ମିଡିଆ': 239506,
#  'десе': 208138,
#  '▁treng': 132275,
#  '▁आतंकवाद': 205810,
#  'ቶም': 13096,
#  '▁minni': 69802,
#  '▁usposab': 203526,
#  '▁সেয়ে': 97945,
#  '▁বৃদ্ধি': 72136,
#  '▁plut': 230779,
#  'भिन्न': 42674,
#  '▁puke': 228170,
#  '平等': 66400,
#  '▁nitu': 54281,
#  '▁rig': 14156,
#  'ዘጋጀ': 247619,
#  '▁khen': 246737,
#  '▁subito': 105668,
#  '▁bitari': 208083,
#  '▁1995': 26736,
#  '顔を': 141778,
#  '▁संशयः': 232829,
#  '両方の': 217891,
#  'ጀት': 143341,
#  'madik': 86096,
#  '▁Uke': 208928,
#  'дел': 13620,
#  '▁dalimi': 222903,
#  '▁ភ្ល': 122360,
#  '▁wodzi': 146138,
#  '▁majalah': 187928,
#  '▁غرفة': 167515,
#  '▁gra': 4384,
#  'ဖိုး': 129841,
#  '▁dostupné': 228245,
#  '▁Kerja': 165826,
#  'embeke': 48787,
#  '▁fikiran': 201769,
#  '▁1967': 64658,
#  '্যৰ': 165458,
#  '▁ਪਰ': 11422,
#  '▁ਘਰ': 49221,
#  'Ү': 249966,
#  '▁офі': 75975,
#  'koht': 161727,
#  '▁बदल': 23535,
#  '▁immers': 200328,
#  'beck': 212123,
#  '▁ekan': 37155,
#  'imis': 11463,
#  '▁சர்': 117496,
#  '▁ikanenu': 136948,
#  'ต่อไป': 142031,
#  '▁Али': 30694,
#  '▁poi': 21963,
#  '▁orðum': 205775,
#  '▁qabu': 27843,
#  'เหตุ': 83011,
#  '▁KA': 57350,
#  '▁sný': 182502,
#  '▁klus': 235348,
#  '▁موعجی': 247339,
#  'erasera': 123682,
#  'folgt': 165715,
#  'בז': 171121,
#  '▁realiz': 33327,
#  'はまだ': 81077,
#  '▁nny': 46255,
#  '證': 252470,
#  '▁kraju': 76529,
#  '▁nyif': 184613,
#  '▁específicos': 191340,
#  '▁veš': 88959,
#  '▁особен': 171831,
#  'klassifikazzjoni': 245513,
#  '▁வேலை': 48674,
#  '▁可能': 172924,
#  'ন্ট': 22486,
#  '▁Cis': 216173,
#  '▁내에서': 138733,
#  'طرف': 176157,
#  '▁informaciją': 70363,
#  '▁anyagok': 214884,
#  'odim': 57124,
#  '▁kadagitoy': 112857,
#  '▁간단히': 237881,
#  '▁kre': 9370,
#  '▁widziałem': 236484,
#  'ekl': 31349,
#  '▁otse': 208959,
#  '▁بخشد': 221542,
#  '椅': 253204,
#  '▁ekonom': 11896,
#  '▁፤': 62840,
#  '앨': 252597,
#  '▁амьдар': 108362,
#  '▁स्यात्': 167129,
#  'PI': 74979,
#  '▁അത': 21850,
#  'abona': 113049,
#  '▁feere': 102199,
#  '▁පොලි': 207794,
#  '▁jü': 206440,
#  '▁Muj': 212540,
#  '▁olet': 32513,
#  '▁gă': 37756,
#  'σχε': 225320,
#  '▁zatvor': 77665,
#  'viranoma': 143266,
#  '▁tinggi': 20599,
#  'ilse': 228289,
#  '▁před': 19188,
#  'འདི་དག་': 137565,
#  '▁nuqqas': 174575,
#  '▁جسم': 66531,
#  '▁ביסט': 170555,
#  '▁Уа': 161130,
#  '▁ñand': 100967,
#  '▁унищо': 247920,
#  '▁સહાય': 112140,
#  '▁இந்தக்': 164007,
#  '尝': 253780,
#  '▁öl': 12864,
#  '▁spelar': 190080,
#  '▁che': 854,
#  'võt': 70207,
#  '▁deed': 88697,
#  '▁Gym': 69981,
#  'میان': 55111,
#  '▁કાર્યક્ર': 148217,
#  '▁கற்று': 154894,
#  'cháin': 51385,
#  '▁גענוג': 201502,
#  '▁neart': 131528,
#  '靠': 252766,
#  'বাসী': 197625,
#  '▁definición': 207226,
#  '▁ikon': 70811,
#  '▁salami': 158513,
#  '▁izlas': 120437,
#  '▁Jaaka': 154545,
#  '▁punyo': 126370,
#  'უ': 248753,
#  'jenza': 55789,
#  '▁ɛmfa': 240982,
#  '▁Ul': 7334,
#  '▁zole': 64988,
#  'шеп': 96993,
#  'kend': 46905,
#  '▁lajang': 197038,
#  '▁sayısı': 163051,
#  '▁болар': 149800,
#  '▁boboto': 98943,
#  'ంతు': 120324,
#  'riżi': 135210,
#  '됐': 251143,
#  '▁자유로운': 226205,
#  'гун': 80971,
#  '▁Stra': 43839,
#  '▁قلبی': 185257,
#  '▁Тому': 70561,
#  'рект': 66093,
#  '举': 252028,
#  '벳': 254687,
#  '▁उदाहरण': 34424,
#  '▁Ios': 203566,
#  '▁3:1-5)': 134274,
#  '▁tɛm': 70024,
#  '分子': 115273,
#  '▁নিশ': 213797,
#  '▁బ్లా': 174548,
#  '▁मत': 14556,
#  'ському': 74689,
#  '▁mengumumkan': 131053,
#  'лли': 18925,
#  '▁کردبوو': 246800,
#  'ುವಂತೆ': 156508,
#  '▁bago': 32837,
#  '▁rumah': 12730,
#  '▁શી': 61045,
#  '▁Apple': 11619,
#  'ктән': 109208,
#  '▁mauaina': 91242,
#  'prang': 159419,
#  'вјет': 188176,
#  '▁đơn': 32770,
#  'henni': 77992,
#  '▁ndoa': 96487,
#  '▁bezala': 36846,
#  '▁andel': 145696,
#  '▁ကယ်': 145677,
#  '▁insig': 112484,
#  '기의': 50792,
#  '▁ā': 12883,
#  '▁ხდება': 115657,
#  '▁Whatever': 224811,
#  '▁জানো': 76101,
#  '▁पु': 3929,
#  '▁gelief': 195086,
#  '塩': 253322,
#  'loidhne': 183117,
#  'חים': 35720,
#  'alment': 55539,
#  '▁kuarta': 140004,
#  '▁wec': 127957,
#  'ћемо': 179891,
#  '▁novej': 204848,
#  'ptin': 129805,
#  '▁Budeme': 217509,
#  '▁ना': 1813,
#  '▁Mã': 225646,
#  '▁Həm': 160781,
#  '▁Sý': 210341,
#  '▁COP': 220652,
#  'ട്ടെ': 51426,
#  'jumus': 36347,
#  '佢哋嘅': 156915,
#  '▁tard': 31876,
#  '\x95': 255368,
#  '▁torn': 31121,
#  '▁veţi': 202483,
#  '▁अहइँ': 17012,
#  '▁гуф': 65255,
#  'itiva': 134451,
#  '-70': 175233,
#  '▁МА': 219138,
#  'ilagi': 92172,
#  'asyo': 133068,
#  '▁યુ': 22570,
#  '▁ekuatiso': 67342,
#  '▁ବନ': 217580,
#  '▁agna': 198786,
#  'ⵉⵔ': 75761,
#  '興奮': 145278,
#  'akela': 214969,
#  '▁buta': 56620,
#  '▁nove': 47869,
#  '▁Stellen': 201901,
#  '▁መጀመሪያ': 145701,
#  'ছি': 7373,
#  '▁불편': 154044,
#  'ವಿತ್ರ': 230439,
#  'ביש': 222681,
#  '▁eýer': 119914,
#  '▁agaghị': 60763,
#  '▁papa': 13476,
#  '▁Vrei': 83223,
#  '▁ababa': 114232,
#  'ێری': 49323,
#  '▁omtsha': 228699,
#  '▁especiais': 223411,
#  '▁kũũ': 55289,
#  '▁dedica': 183038,
#  '▁kwamen': 247538,
#  'níomh': 86566,
#  '▁ئوي': 43346,
#  '▁ಸತ್ಯ': 126752,
#  '▁తరువాత': 53853,
#  '▁ರಾತ್ರಿ': 173342,
#  'innay': 226453,
#  '▁kiwari': 225096,
#  '的一': 42706,
#  '▁konkurenc': 171929,
#  '▁aizsardzību': 205965,
#  'adoo': 84782,
#  '▁Liệu': 240976,
#  'uaian': 220194,
#  '▁batila': 240851,
#  '▁komu': 71483,
#  '▁ମ୍ୟାଚ୍': 228077,
#  '▁학교에': 174989,
#  'தானே': 238388,
#  '▁Storbritannia': 177874,
#  '▁joiden': 83486,
#  'ístico': 170990,
#  'ಾಗಿ': 3946,
#  '▁Pagkatapos': 107422,
#  '▁mềm': 87366,
#  '▁onim': 125284,
#  '▁hooy': 187428,
#  '▁เท่ากับ': 223071,
#  '▁raoodo': 164312,
#  'ɗa': 22920,
#  'جاغام': 146116,
#  'रेट': 128459,
#  'пит': 101350,
#  '処': 250978,
#  '▁šiol': 199257,
#  '▁Ö': 7519,
#  '▁แห': 189927,
#  '▁ekspo': 131473,
#  '▁پىكى': 161901,
#  '▁atšķ': 191384,
#  '▁kran': 136216,
#  'Kĩ': 201549,
#  '▁zozn': 180705,
#  'ayapaan': 195759,
#  'ボール': 119744,
#  '▁tomorrow': 103005,
#  'మని': 45158,
#  'ホール': 199335,
#  'ómhair': 159229,
#  'boll': 230580,
#  'ძღვან': 228487,
#  '▁финансо': 86635,
#  '▁सबेन्ह': 194678,
#  '▁илэрхий': 178444,
#  '▁الساعة': 182950,
#  '-2019': 227995,
#  '▁pratik': 155407,
#  '▁шөғөл': 158743,
#  '▁Antes': 98000,
#  '▁korek': 163822,
#  'Ech': 213907,
#  '▁ਮਜ਼': 105916,
#  'ッド': 23821,
#  '▁합니까': 85752,
#  '▁хар': 24988,
#  '▁खुसी': 120111,
#  '▁Ronald': 113361,
#  '▁voorbeeld': 108090,
#  'гир': 77226,
#  'umbul': 42854,
#  '▁maasem': 180644,
#  'ਹੁੰ': 69473,
#  'ranin': 200145,
#  '▁မျိုး': 101509,
#  'ekiya': 85998,
#  '되지만': 217893,
#  'ຜ່ອນ': 239434,
#  '▁उत्सा': 108868,
#  'ልን': 46145,
#  '▁कं': 112653,
#  '▁يعيش': 144834,
#  'zho_Hans': 256200,
#  '▁هكذا': 105986,
#  '▁Tento': 64174,
#  'ról': 38045,
#  '务': 251191,
#  '▁укључује': 224369,
#  'zjoni': 12260,
#  '▁ئۆتۆمبێ': 204898,
#  'ītas': 61066,
#  '▁mantener': 132721,
#  '▁voqea': 217340,
#  '▁quddi': 62682,
#  '▁country': 34881,
#  '▁rregull': 116970,
#  '然': 249882,
#  '▁ಆಗಿದೆ': 142516,
#  'uales': 76335,
#  '▁ɔn': 32689,
#  '▁carri': 104779,
#  'веро': 106549,
#  '▁berri': 90717,
#  'asteri': 166638,
#  'areka': 185543,
#  '▁yĩ': 6191,
#  '▁ɲɛ': 20080,
#  '▁жабдықтау': 216957,
#  '▁loja': 141967,
#  '▁고등': 144582,
#  '▁რამეთუ': 131942,
#  '▁skrin': 203611,
#  '▁seniň': 126759,
#  '▁लड़ा': 113704,
#  '▁kräver': 247162,
#  '▁Monate': 213433,
#  '▁آلو': 208145,
#  '▁پی': 3246,
#  '▁pangguna': 98523,
#  '▁DIY': 145091,
#  '▁ይችላል።': 88075,
#  '▁Niko': 58502,
#  '▁दृश्यते': 220591,
#  '▁rû': 108259,
#  '▁keterampilan': 104660,
#  'cara': 8031,
#  'ରକୁ': 99991,
#  '▁pār': 5754,
#  '治疗': 237844,
#  'völd': 242935,
#  '▁pamwe': 52757,
#  '▁batlhanka': 143509,
#  '▁Sobre': 106913,
#  '▁това': 7540,
#  ']".': 38567,
#  '▁Usted': 108581,
#  'サイズ': 111195,
#  '▁zurück': 39208,
#  '▁avoir': 33356,
#  'esk': 21252,
#  'føring': 83521,
#  '▁queen': 203362,
#  'пуск': 93590,
#  'पै': 86930,
#  'fua': 26154,
#  '▁byiza': 80592,
#  '▁neved': 173054,
#  '▁trống': 230130,
#  '▁күтәр': 138402,
#  '▁Francijas': 237490,
#  '▁مالذي': 195996,
#  '๊ย': 171367,
#  '▁rhod': 130228,
#  '▁26': 4630,
#  '▁pembang': 88442,
#  'മ': 248648,
#  'рақ': 21079,
#  'ましたが': 148467,
#  '▁ਸੁਰੱਖਿਅਤ': 179208,
#  '▁מסת': 90641,
#  'پێش': 196046,
#  '▁ഭാര്യ': 125032,
#  'བུད་མེད་': 139230,
#  'dren': 233440,
#  '▁124': 132638,
#  '▁gwɛn': 191610,
#  'wla': 182084,
#  'ufasha': 111312,
#  '▁jibha': 132325,
#  'ību': 5989,
#  'дө': 9930,
#  '▁단순히': 77764,
#  '▁engel': 134942,
#  '▁완료': 85766,
#  'fras': 193551,
#  '▁സോ': 129073,
#  '▁agto': 183508,
#  '▁اتدي': 50328,
#  '▁reli': 26100,
#  '▁nič': 32060,
#  'තු': 8638,
#  'ilder': 155688,
#  '▁처럼': 100271,
#  '▁napor': 236412,
#  'ਵਨ': 72591,
#  '▁Многу': 128241,
#  '▁enseñ': 121518,
#  '▁അവസാന': 66597,
#  'ýin': 230566,
#  'വാദ': 116937,
#  '▁müz': 158213,
#  '▁сығы': 67793,
#  'ோஷ': 220459,
#  '▁бак': 94284,
#  'batan': 42472,
#  '▁Цяпер': 198697,
#  '▁উত': 107496,
#  '▁diozu': 114746,
#  'ਹੋ': 51741,
#  '▁最高': 194075,
#  'iseen': 24951,
#  '▁hadday': 130943,
#  '▁kwere': 74175,
#  '▁قىلىمىز': 100786,
#  'ිය': 1801,
#  '▁تاش': 56493,
#  'akanĩ': 87819,
#  'onra': 65179,
#  '▁nyaka': 20107,
#  '-2-': 232038,
#  '▁beyin': 244885,
#  '▁Tich': 169936,
#  '▁airson': 12080,
#  '▁ٹھیک': 112059,
#  '▁그렇지': 52805,
#  '一つ': 45154,
#  '▁drá': 243327,
#  '▁שלום': 152872,
#  '▁이민': 112828,
#  '▁सगळं': 167860,
#  '▁améli': 147089,
#  '▁aýdy': 59720,
#  'িন্': 74661,
#  '▁yaka': 16678,
#  'heq': 108664,
#  '▁содржи': 104400,
#  '▁valandų': 232004,
#  '▁מחקר': 212568,
#  'élite': 236209,
#  '▁телә': 18990,
#  '▁Num': 23167,
#  '▁thuê': 128020,
#  '▁төшөр': 108459,
#  'atsara': 208834,
#  'っていました': 38102,
#  '▁κρί': 147265,
#  '▁Bezug': 161165,
#  '▁전반': 176814,
#  '▁Eku': 34234,
#  '▁berp': 24903,
#  'အရာ': 58852,
#  'ikulu': 19812,
#  'inote': 130738,
#  'ਿਵ': 216277,
#  '俺': 251081,
#  'すす': 140966,
#  'と比較': 172481,
#  'joita': 179349,
#  'miia': 210226,
#  '▁iyali': 185573,
#  '▁respective': 162485,
#  '▁opfattelse': 233754,
#  '▁פל': 123398,
#  'зын': 230210,
#  'ulom': 234802,
#  'デン': 59185,
#  '▁kinh': 19590,
#  '▁vår': 17116,
#  'vwa': 14496,
#  '▁dřív': 220808,
#  'म्ह': 228608,
#  '▁risik': 160231,
#  '▁iska': 43294,
#  'jonga': 105112,
#  '▁ved': 3033,
#  'ጡት': 134287,
#  '▁kasemp': 170318,
#  'emble': 43574,
#  'ロス': 188901,
#  '▁podstat': 159929,
#  '▁zagot': 97611,
#  '▁Ако': 13701,
#  '▁othi': 171396,
#  '▁nähd': 84866,
#  'ချစ်': 121461,
#  '▁त्याला': 35460,
#  '▁ನಿಯಮ': 110514,
#  '▁Course': 236795,
#  '▁subur': 189251,
#  'ଡିଆ': 93954,
#  'สี': 121091,
#  'тні': 40642,
#  'āj': 9013,
#  'yita': 219145,
#  '者たちが': 212961,
#  '▁malai': 132857,
#  'şte': 14987,
#  '▁دوروب': 242268,
#  '▁kwụsị': 147415,
#  '▁Vors': 216317,
#  'Kau': 203301,
#  'ⵓⵜ': 42908,
#  '▁ගත්තේ': 183632,
#  '▁Fie': 197404,
#  '▁asiakka': 128551,
#  '▁በመ': 13744,
#  '▁Pʋyɔɔ': 243781,
#  'nič': 30119,
#  '▁pareiškė': 169024,
#  'jeća': 52558,
#  'ಿಕೊಳ್ಳಲು': 131945,
#  '▁kullanarak': 233084,
#  '▁kambele': 246437,
#  '▁ndyangu': 47946,
#  '▁maendeleo': 172738,
#  'weer': 146364,
#  '▁antontan': 238151,
#  '▁leita': 93445,
#  'бра': 6866,
#  'ասար': 200961,
#  '▁རྗེའི': 148939,
#  'ულს': 159197,
#  '?",': 52661,
#  '▁よって': 232078,
#  'ப்படுத்து': 140398,
#  '▁деклара': 117602,
#  '▁kalo': 3886,
#  'ल्डिंग': 190695,
#  '▁বলে': 17476,
#  '▁perten': 75911,
#  'maj': 186445,
#  'བོད་': 166308,
#  '▁ว่า': 32473,
#  '▁malonda': 115440,
#  'faq': 81784,
#  '▁kamach': 119003,
#  '▁Faoi': 203127,
#  'vanju': 43722,
#  '▁Constitution': 245899,
#  '▁대개': 178679,
#  '▁Click': 154814,
#  'σπα': 130635,
#  'देव': 76849,
#  'τηκα': 149506,
#  'olobha': 143419,
#  '▁ehtimol': 210856,
#  'ambene': 205633,
#  'sitwazzjoni': 123313,
#  '▁selanjutnya': 145273,
#  'ရယ်သံများ': 88410,
#  '▁mennyiség': 166370,
#  'akte': 55195,
#  '▁amaningi': 112535,
#  '▁nego': 11714,
#  '▁Kitty': 185774,
#  '▁apuruuk': 172728,
#  'ема': 111860,
#  '▁varten': 79207,
#  '▁kombele': 181038,
#  'ედ': 21402,
#  '▁Esekiele': 217088,
#  'គោល': 241469,
#  '▁भन्छ': 222860,
#  '▁donya': 43046,
#  '▁Һеҙҙең': 189565,
#  'vé': 5418,
#  '▁gebracht': 98318,
#  '見て': 86208,
#  '▁Edene': 129045,
#  'gment': 150076,
#  '最小': 133678,
#  'အမြ': 128858,
#  '▁bħ': 11684,
#  '▁Pau': 116840,
#  '▁nive': 116128,
#  '▁किन': 24934,
#  'desmit': 206628,
#  '▁ફર': 71387,
#  '▁ទូល': 127625,
#  '▁mahaifin': 212913,
#  '▁Ruri': 98136,
#  '▁واسئ': 78666,
#  'ધી': 14031,
#  '▁pom': 6122,
#  '▁ვიდე': 189424,
#  'fakwa': 239782,
#  '念': 250527,
#  '▁kimfumu': 187815,
#  'Pɩ': 241648,
#  'әһ': 8062,
#  '▁mpimpa': 218244,
#  '▁Upépe': 238606,
#  'ستانه': 226920,
#  '▁доза': 176380,
#  '▁কেনেকৈ': 161922,
#  'sze': 60222,
#  'ግዚአብ': 20326,
#  'បញ្ជាក់': 187354,
#  '▁emhlabeni': 32715,
#  'ண்ணு': 217422,
#  '▁Plaz': 192363,
#  'íku': 156849,
#  'ทิ้ง': 135388,
#  '▁menginginkan': 157683,
#  '▁wah': 12071,
#  '▁Tɔ': 73176,
#  '▁зүр': 134877,
#  '▁이주': 218145,
#  '▁आंतर': 104389,
#  '▁bege': 115289,
#  '▁kapangyarihan': 141235,
#  '▁NG': 80048,
#  '▁кетти': 171270,
#  '▁실': 5914,
#  '▁vamanji': 36437,
#  '▁Jakob': 64470,
#  '▁ਮੰਤਰੀ': 55767,
#  '▁indispensa': 145272,
#  '▁کرنا': 26132,
#  '▁Ol': 3590,
#  '▁mapema': 135455,
#  '▁հրաժար': 223386,
#  '▁diag': 30650,
#  '▁didesnė': 223062,
#  '▁duchov': 173073,
#  'гузор': 192555,
#  '按照': 147248,
#  '▁बनाना': 153059,
#  'illance': 124060,
#  'ਸ਼ਟਰ': 104736,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# พวกเขา
# ยืน
# กล้า
# ศัพท์
# เท่าไหร่
# จํา
# นัก
# เพิ่ม
# ื่อน
# ▁สิ่งที่
# ได้รับ
# ุ่ง
# สิ้น
# ็จ
# ออก
# ข้อมูล
# ดูเหมือน
# ▁พวก
# โอ
# ไกล

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04819674, -0.02600676],
#        [ 0.0212226 , -0.00798357],
#        [ 0.03820447, -0.01199786],
#        [-0.02440003,  0.03178945]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54e7138a-64cc-4876-b24e-cb08816e743c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54e7138a-64cc-4876-b24e-cb08816e743c")) {                    Plotly.newPlot(                        "54e7138a-64cc-4876-b24e-cb08816e743c",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[-0.042036712,-0.04823325,0.0024289265,0.049544368,-0.036454476,-0.04092772,-0.0017296672,0.037053976,0.03936502,-0.041520916,0.010841049,0.04696374,-0.021233618,0.03649323,-0.013080575,-0.032374874,0.03224503,0.023682658,0.03821032,0.000035382807,-0.015584089,0.04273499,0.026239004,0.010747038,0.035721604,-0.023084844,-0.02162875,0.0077549703,0.04528706,-0.034505166,0.029477563,-0.042225875,0.04847342,0.03451482,0.019492362,0.0212227,0.04420718,0.03003608,-0.018989695,0.04976512,0.03763486,0.02643213,0.039218772,0.02826656,-0.009623945,-0.049286593,-0.015650012,-0.047809638,0.026038121,0.03597479,-0.0066516995,0.008283664,0.02937119,0.036119107,0.019149903,-0.025314916,0.025768254,-0.021803474,0.012708399,0.0033091195,-0.020625437,-0.0064162724,0.0017756112,-0.012800753,0.014982615,-0.019550765,0.011330865,0.044216488,-0.033370614,-0.04878738,0.0483088,-0.013849795,0.0049109347,0.008726001,-0.004652966,0.027572323,0.0100671165,0.03642783,-0.02183857,-0.025861694,-0.01500852,0.016107786,-0.04182621,-0.016539205,-0.0143922195,0.031021524,0.006796051,0.044643532,-0.034052923,-0.041019022,0.039600004,-0.034976147,0.037089292,-0.01292181,0.046833668,-0.04508524,0.03254931,0.007557951,0.043182086,-0.018896747,-0.04762764,0.015026782,-0.030623151,0.040703986,0.0044818297,-0.0464386,0.0354187,0.018756423,-0.049730767,-0.04073323,0.030461196,-0.016448475,0.03060421,0.003239788,-0.00847441,0.030571405,-0.022722293,0.04951192,0.044188473,-0.013570271,0.023958053,0.04983567,-0.0021635294,-0.04103292,0.040454436,0.0044561625,-0.028892506,0.016362105,0.04168764,0.011242282,0.04564741,0.008140612,0.007698536,-0.034055293,-0.0048763156,-0.04367242,0.017004635,0.04199541,-0.040447723,0.027996492,0.013912309,-0.0004298091,0.018600214,0.022396792,0.035214607,-0.016033567,0.035510685,-0.017026208,0.009371888,0.019301843,0.04659083,0.04456568,0.037545774,-0.039659727,-0.047312688,0.020186152,-0.009684335,-0.016500007,-0.0314252,0.041257206,-0.03363289,-0.00785166,0.03387134,-0.031047523,0.047461357,-0.03498306,-0.01408305,-0.022057617,-0.022606874,0.03191823,0.048780654,0.017103683,0.0050069913,-0.02726767,0.023856413,0.01216688,-0.013937689,0.03835057,0.028893266,-0.048533704,0.004502427,0.022426162,-0.04799018,-0.040429782,0.0004918948,-0.037906907,-0.03044573,-0.047079623,-0.038039304,-0.021196926,0.02206571,-0.037718713,0.021030676,-0.038048018,-0.0193012,-0.00948336,-0.018824851,0.0037455931,-0.031657435,-0.04157295,-0.0051007643,-0.039080597,0.00015112013,0.023336861,-0.0041220784,0.04735178,0.04342333,0.040710937,0.002082087,-0.031297136,-0.020752167,-0.034707166,-0.021860266,0.013817918,-0.0042481534,-0.017742254,0.047523085,0.029025104,-0.01890415,0.035844553,0.027280543,0.013238717,-0.032450963,0.040446866,0.00081281736,-0.038939167,-0.037702024,0.010912348,-0.040836502,-0.008793436,0.015908863,0.034675527,-0.032929562,-0.006385397,-0.0093427785,0.02315085,0.00040299818,-0.00034996122,0.045465354,0.024367642,-0.044675946,0.02539878,-0.037741352,0.047393594,-0.0037627816,0.024842296,0.048792552,-0.02951393,-0.040511023,0.021287095,-0.035582732,0.0043832287,-0.043435004,-0.03584839,-0.0030253641,-0.039622914,-0.0084146485,0.04697969,-0.0098566525,0.035512272,-0.034648407,-0.008010328,0.007708214,-0.049832214,0.01982167,0.044527296,0.021566998,0.008328091,0.046812925,0.0076220743,-0.016485132,0.024534587,0.0012574308, ...
# Default initializer range  -0.049997784 0.049998548
# Glorot initializer range  -0.01095396 0.01095383

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a5f285c2-eb02-4151-947a-c4b915c3b6d6" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5f285c2-eb02-4151-947a-c4b915c3b6d6")) {                    Plotly.newPlot(                        "a5f285c2-eb02-4151-947a-c4b915c3b6d6",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04819674, -0.02600676],
#        [ 0.0212226 , -0.00798357],
#        [ 0.03820447, -0.01199786],
#        [-0.02440003,  0.03178945]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[-0.001704  ,  0.01340028],
#        [ 0.00028771,  0.00779478],
#        [ 0.00122849,  0.01532863],
#        [ 0.00643687,  0.00338772]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.02280616, -0.01186184],
#        [ 0.0127192 , -0.00284728],
#        [ 0.02472923, -0.00349926],
#        [ 0.00282897,  0.01876348]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[-2.9299408e-06,  1.8465750e-02, -3.3028796e-04,  2.4969755e-02],
#        [ 3.1460049e-03,  9.4335955e-03,  2.2414122e-03,  1.1875333e-02],
#        [ 7.8177778e-03,  1.7873764e-02,  5.6688059e-03,  2.1980327e-02],
#        [ 1.6902279e-02, -2.3539728e-03,  1.2984455e-02, -7.9138139e-03]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[-1.9781369e-04 -5.9827889e-05 -8.9029723e-05  2.4661532e-04]
#  [-8.5898871e-05 -1.8534496e-05 -2.0161142e-05  1.4707108e-04]
#  [-1.5380845e-04 -2.8019460e-05 -2.3259190e-05  2.9109366e-04]
#  [ 1.0661555e-04  7.2225950e-05  1.4732419e-04  8.1775208e-05]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.24996947 0.24999385 0.24998868 0.250048  ]
#  [0.24998383 0.24999574 0.24999546 0.250025  ]
#  [0.249969   0.24999125 0.2499921  0.25004765]
#  [0.25000083 0.24999474 0.25000802 0.24999644]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.00696649 0.01085385 0.00514165 0.01272644]
#  [0.00696616 0.01085431 0.00514139 0.01272715]
#  [0.0069665  0.01085388 0.00514166 0.01272647]
#  [0.00696577 0.0108549  0.00514108 0.01272806]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.00696649 0.01085385 0.00514165 0.01272644]
#  [0.00696616 0.01085431 0.00514139 0.01272715]
#  [0.0069665  0.01085388 0.00514166 0.01272647]
#  [0.00696577 0.0108549  0.00514108 0.01272806]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.00810767]
#  [0.00810773]
#  [0.00810769]
#  [0.00810782]]

# %%
tf.random.set_seed(123)

block_size = embedded_sentence.shape[0]   # [T, d_in] → T = sequence length

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.00810767 0.00765592 0.01205995]
#  [0.00810773 0.00765639 0.01205977]
#  [0.00810769 0.00765584 0.0120599 ]
#  [0.00810782 0.00765686 0.01205947]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
